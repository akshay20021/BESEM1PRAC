# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return (x+3)**2

def df(x):
    return 2*x + 6

def gradient_descent(initial_x, learning_rate, num_iterations):
    x=initial_x
    x_history=[x]
    for i in range(num_iterations):
        gradient=df(x)
        x=x- learning_rate * gradient
        x_history.append(x)
    return x, x_history

initial_x=2
learning_rate= 0.01
num_iterations= 90

x , x_history = gradient_descent(initial_x, learning_rate, num_iterations)
print("Local minimum:{}".format(x))
for i in range(len(x_history)):
    print(f"Iterator number {i}: {x_history[i]}")
# Out:
# Local minimum:-2.188447132392417
# Iterator number 0: 2
# Iterator number 1: 1.9
# Iterator number 2: 1.8019999999999998
# Iterator number 3: 1.70596
# Iterator number 4: 1.6118408
# Iterator number 5: 1.519603984
# Iterator number 6: 1.42921190432
# Iterator number 7: 1.3406276662336
# Iterator number 8: 1.253815112908928
# Iterator number 9: 1.1687388106507495
# Iterator number 10: 1.0853640344377344
# Iterator number 11: 1.0036567537489798
# Iterator number 12: 0.9235836186740002
# Iterator number 13: 0.8451119463005202
# Iterator number 14: 0.7682097073745098
# Iterator number 15: 0.6928455132270196
# Iterator number 16: 0.6189886029624792
# Iterator number 17: 0.5466088309032295
# Iterator number 18: 0.4756766542851649
# Iterator number 19: 0.40616312119946163
# Iterator number 20: 0.3380398587754724
# Iterator number 21: 0.27127906159996296
# Iterator number 22: 0.2058534803679637
# Iterator number 23: 0.14173641076060442
# Iterator number 24: 0.07890168254539233
# Iterator number 25: 0.017323648894484484
# Iterator number 26: -0.04302282408340521
# Iterator number 27: -0.10216236760173711
# Iterator number 28: -0.16011912024970237
# Iterator number 29: -0.21691673784470833
# Iterator number 30: -0.27257840308781417
# Iterator number 31: -0.3271268350260579
# Iterator number 32: -0.38058429832553675
# Iterator number 33: -0.432972612359026
# Iterator number 34: -0.4843131601118455
# Iterator number 35: -0.5346268969096086
# Iterator number 36: -0.5839343589714164
# Iterator number 37: -0.632255671791988
# Iterator number 38: -0.6796105583561483
# Iterator number 39: -0.7260183471890252
# Iterator number 40: -0.7714979802452447
# Iterator number 41: -0.8160680206403399
# Iterator number 42: -0.8597466602275331
# Iterator number 43: -0.9025517270229825
# Iterator number 44: -0.9445006924825228
# Iterator number 45: -0.9856106786328723
# Iterator number 46: -1.025898465060215
# Iterator number 47: -1.0653804957590107
# Iterator number 48: -1.1040728858438305
# Iterator number 49: -1.1419914281269539
# Iterator number 50: -1.1791515995644148
# Iterator number 51: -1.2155685675731265
# Iterator number 52: -1.2512571962216639
# Iterator number 53: -1.2862320522972306
# Iterator number 54: -1.320507411251286
# Iterator number 55: -1.3540972630262602
# Iterator number 56: -1.387015317765735
# Iterator number 57: -1.4192750114104202
# Iterator number 58: -1.4508895111822118
# Iterator number 59: -1.4818717209585675
# Iterator number 60: -1.512234286539396
# Iterator number 61: -1.5419896008086083
# Iterator number 62: -1.571149808792436
# Iterator number 63: -1.5997268126165873
# Iterator number 64: -1.6277322763642557
# Iterator number 65: -1.6551776308369706
# Iterator number 66: -1.6820740782202313
# Iterator number 67: -1.7084325966558267
# Iterator number 68: -1.7342639447227102
# Iterator number 69: -1.759578665828256
# Iterator number 70: -1.784387092511691
# Iterator number 71: -1.808699350661457
# Iterator number 72: -1.832525363648228
# Iterator number 73: -1.8558748563752634
# Iterator number 74: -1.8787573592477582
# Iterator number 75: -1.901182212062803
# Iterator number 76: -1.923158567821547
# Iterator number 77: -1.9446953964651161
# Iterator number 78: -1.9658014885358137
# Iterator number 79: -1.9864854587650975
# Iterator number 80: -2.0067557495897956
# Iterator number 81: -2.026620634598
# Iterator number 82: -2.04608822190604
# Iterator number 83: -2.065166457467919
# Iterator number 84: -2.0838631283185607
# Iterator number 85: -2.1021858657521895
# Iterator number 86: -2.1201421484371457
# Iterator number 87: -2.137739305468403
# Iterator number 88: -2.1549845193590347
# Iterator number 89: -2.171884828971854
# Iterator number 90: -2.188447132392417

# %%
x_vals=np.linspace(-11,5,50)
plt.plot(x_vals ,f(x_vals))
plt.plot(x_history , f(np.array(x_history)), 'rx')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gradient Descent')
plt.show()
